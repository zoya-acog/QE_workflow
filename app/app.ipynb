# %%
# advQMcalc_test — QM Crystal Workflow
import sys
from pathlib import Path

_app_dir = Path.cwd()
if str(_app_dir) not in sys.path:
    sys.path.insert(0, str(_app_dir))

from app_src import app

my_app = app(app_mode=True, debug=False)
my_app.form

# %%
#  © 2017-26. Aganitha.ai cognitive solutions private limited. Proprietary and Confidential.
